# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df_up = pd.read_csv(r'F0/total_number_up.dat', sep = '\t', header = None)
df1_up = pd.read_csv(r'F0/total_number_dn.dat', sep = '\t', header = None)

df_dn = pd.read_csv(r'F0/total_number_dn.dat', sep = '\t', header = None)
df1_dn = pd.read_csv(r'F0/density_dn.dat', sep = '\t', header = None)

df2 = pd.read_csv(r'F0/purity.dat', sep = '\t', header = None)

time = np.array(df_up.iloc[:, 1])
number_tot_up = np.array(df_up.iloc[:, 2])
number_tot_dn = np.array(df_dn.iloc[:, 2])


purity = 1-np.array(df2.iloc[:, 2])
#plt.plot(time, number, '-o')
plt.plot(time, number_tot_up, label = r'$N_{\uparrow}$')
plt.plot(time, number_tot_dn, label = r'$N_{\downarrow}$')
plt.plot(time, number_tot_up+number_tot_dn, label = r'$N_{tot}$')

plt.grid(visible = True)

plt.legend()
